# %% [markdown]
# # EDA

# %%
import pandas as pd

# %%
# Train dataset
pd.read_csv("data/adult.data", names= ["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race",
                                          "sex", "capital-gain", "capital-loss","hours-per-week","native-country","income"], header=None)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df= pd.read_csv("data/adult.data", names= ["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race",
                                          "sex", "capital-gain", "capital-loss","hours-per-week","native-country","income"], header=None)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 24

# %%
df[df.duplicated()]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (32537, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
## Numerical and categorical columns

numerical_columns = df.columns[df.dtypes != "object"]
categorical_columns = df.columns[df.dtypes == "object"]

# %%
numerical_columns
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %%
categorical_columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'income'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K

# %%
df[numerical_columns].describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32537.0      38.585549      13.637984     17.0      28.0
# fnlwgt          32537.0  189780.848511  105556.471009  12285.0  117827.0
# education-num   32537.0      10.081815       2.571633      1.0       9.0
# capital-gain    32537.0    1078.443741    7387.957424      0.0       0.0
# capital-loss    32537.0      87.368227     403.101833      0.0       0.0
# hours-per-week  32537.0      40.440329      12.346889      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  236993.0  1484705.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %%
df[categorical_columns].describe().T
# Out:
#                 count unique                  top   freq
# workclass       32537      9              Private  22673
# education       32537     16              HS-grad  10494
# marital-status  32537      7   Married-civ-spouse  14970
# occupation      32537     15       Prof-specialty   4136
# relationship    32537      6              Husband  13187
# race            32537      5                White  27795
# sex             32537      2                 Male  21775
# native-country  32537     42        United-States  29153
# income          32537      2                <=50K  24698

# %% [markdown]
# # Graphs based analysis

# %%
# Plot all numerical features

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
plt.suptitle("Univariate analysis of numerical features", fontsize=20, fontweight="bold", alpha = 0.8, y =1.)

for i in range(0, len(numerical_columns)):
    plt.subplot(2,3,i+1)
    sns.kdeplot(df, x=numerical_columns[i], fill = True, color = 'r')
    plt.xlabel(numerical_columns[i])
    plt.tight_layout()

# %%
# Plot all categorical features

plt.figure(figsize=(15,15))
plt.suptitle("Univariate analysis of categorical features",fontsize=20, fontweight = "bold", alpha = 0.8, y=1.)

for i in range(0, len(categorical_columns)):
    plt.subplot(4,3,i+1)
    sns.countplot(df, y = categorical_columns[i], palette = "Set2")
    plt.ylabel(categorical_columns[i])
    #plt.xticks(rotation = 90)
    plt.tight_layout()
# Out:
# C:\Users\manoh\AppData\Local\Temp\ipykernel_16720\2377086389.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, y = categorical_columns[i], palette = "Set2")
# C:\Users\manoh\AppData\Local\Temp\ipykernel_16720\2377086389.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, y = categorical_columns[i], palette = "Set2")
# C:\Users\manoh\AppData\Local\Temp\ipykernel_16720\2377086389.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, y = categorical_columns[i], palette = "Set2")
# ...

# %%
df[numerical_columns].corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076447       0.036224      0.077676      0.057745
# fnlwgt         -0.076447  1.000000      -0.043388      0.000429     -0.010260
# education-num   0.036224 -0.043388       1.000000      0.122664      0.079892
# capital-gain    0.077676  0.000429       0.122664      1.000000     -0.031639
# capital-loss    0.057745 -0.010260       0.079892     -0.031639      1.000000
# hours-per-week  0.068515 -0.018898       0.148422      0.078408      0.054229
#
#                 hours-per-week
# age                   0.068515
# fnlwgt               -0.018898
# education-num         0.148422
# capital-gain          0.078408
# capital-loss          0.054229
# hours-per-week        1.000000

# %%
# Heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
# pairplot
sns.pairplot(df.sample(n=10000))

# %%
# Bivariate analysis

# Education and Income count

df.groupby(['education'])["income"].value_counts().reset_index()
# Out:
#         education  income  count
# 0            10th   <=50K    871
# 1            10th    >50K     62
# 2            11th   <=50K   1115
# 3            11th    >50K     60
# 4            12th   <=50K    400
# 5            12th    >50K     33
# 6         1st-4th   <=50K    160
# 7         1st-4th    >50K      6
# 8         5th-6th   <=50K    316
# 9         5th-6th    >50K     16
# 10        7th-8th   <=50K    605
# 11        7th-8th    >50K     40
# 12            9th   <=50K    487
# 13            9th    >50K     27
# 14     Assoc-acdm   <=50K    802
# 15     Assoc-acdm    >50K    265
# 16      Assoc-voc   <=50K   1021
# 17      Assoc-voc    >50K    361
# 18      Bachelors   <=50K   3132
# 19      Bachelors    >50K   2221
# 20      Doctorate    >50K    306
# 21      Doctorate   <=50K    107
# 22        HS-grad   <=50K   8820
# 23        HS-grad    >50K   1674
# 24        Masters    >50K    959
# 25        Masters   <=50K    763
# 26      Preschool   <=50K     50
# ...

# %%
edu_inc_df = df.groupby(['education'])["income"].value_counts().reset_index()

# %%
plt.figure(figsize=(10,10))
plt.suptitle("Bivariate Analysis between education and income categories", fontsize=20, fontweight="bold", alpha=0.8, y=1.)
sns.barplot(edu_inc_df, y="education",x="count", hue="income", palette="Set2")
plt.tight_layout()

# %%
# Oberservation : Individuals with higher level of education tend to make more than 50k

# %%
# Bivariate analysis between workclass and income categories

work_inc_df = df.groupby(['workclass'])["income"].value_counts().reset_index()

plt.figure(figsize=(10,6))
plt.suptitle("Bivariate Analysis between education and income categories", fontsize=20, fontweight="bold", alpha=0.8, y=1.)
sns.barplot(work_inc_df, y="workclass",x="count", hue="income", palette="hls")
plt.tight_layout()

# %%
# Bivariate analysis between workclass and income categories interms of percentage

df1 = df.groupby(['workclass'])["income"].value_counts().reset_index()

# %%
df1.groupby("workclass")["count"].sum().reset_index()
# Out:
#            workclass  count
# 0                  ?   1836
# 1        Federal-gov    960
# 2          Local-gov   2093
# 3       Never-worked      7
# 4            Private  22673
# 5       Self-emp-inc   1116
# 6   Self-emp-not-inc   2540
# 7          State-gov   1298
# 8        Without-pay     14

# %%
df2 = df1.groupby("workclass")["count"].sum().reset_index()

# %%
df1.merge(df2, on="workclass", how="left")
# Out:
#             workclass  income  count_x  count_y
# 0                   ?   <=50K     1645     1836
# 1                   ?    >50K      191     1836
# 2         Federal-gov   <=50K      589      960
# 3         Federal-gov    >50K      371      960
# 4           Local-gov   <=50K     1476     2093
# 5           Local-gov    >50K      617     2093
# 6        Never-worked   <=50K        7        7
# 7             Private   <=50K    17712    22673
# 8             Private    >50K     4961    22673
# 9        Self-emp-inc    >50K      622     1116
# 10       Self-emp-inc   <=50K      494     1116
# 11   Self-emp-not-inc   <=50K     1816     2540
# 12   Self-emp-not-inc    >50K      724     2540
# 13          State-gov   <=50K      945     1298
# 14          State-gov    >50K      353     1298
# 15        Without-pay   <=50K       14       14

# %%
work_inc_df = df1.merge(df2, on="workclass", how="left")

work_inc_df = work_inc_df.rename(columns={"count_x" : "workclass_inc_count", "count_y" : "workclass_total_count"})

# %%
work_inc_df
# Out:
#             workclass  income  workclass_inc_count  workclass_total_count
# 0                   ?   <=50K                 1645                   1836
# 1                   ?    >50K                  191                   1836
# 2         Federal-gov   <=50K                  589                    960
# 3         Federal-gov    >50K                  371                    960
# 4           Local-gov   <=50K                 1476                   2093
# 5           Local-gov    >50K                  617                   2093
# 6        Never-worked   <=50K                    7                      7
# 7             Private   <=50K                17712                  22673
# 8             Private    >50K                 4961                  22673
# 9        Self-emp-inc    >50K                  622                   1116
# 10       Self-emp-inc   <=50K                  494                   1116
# 11   Self-emp-not-inc   <=50K                 1816                   2540
# ...

# %%
work_inc_df["percent"] = round((work_inc_df["workclass_inc_count"]/work_inc_df["workclass_total_count"])*100, 2)

# %%
work_inc_df
# Out:
#             workclass  income  workclass_inc_count  workclass_total_count  \
# 0                   ?   <=50K                 1645                   1836
# 1                   ?    >50K                  191                   1836
# 2         Federal-gov   <=50K                  589                    960
# 3         Federal-gov    >50K                  371                    960
# 4           Local-gov   <=50K                 1476                   2093
# 5           Local-gov    >50K                  617                   2093
# 6        Never-worked   <=50K                    7                      7
# 7             Private   <=50K                17712                  22673
# 8             Private    >50K                 4961                  22673
# 9        Self-emp-inc    >50K                  622                   1116
# 10       Self-emp-inc   <=50K                  494                   1116
# 11   Self-emp-not-inc   <=50K                 1816                   2540
# ...

# %%
plt.figure(figsize=(10,6))
plt.suptitle("Bivariate Analysis between workclass and income categories in percentage", fontsize=20, fontweight="bold", alpha=0.8, y=1.)
sns.barplot(work_inc_df, y="workclass",x="percent", hue="income", palette="hls")
plt.tight_layout()

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
# Bivariate analysis between marital-status and income

df.groupby("marital-status")["income"].value_counts().reset_index()
# Out:
#             marital-status  income  count
# 0                 Divorced   <=50K   3978
# 1                 Divorced    >50K    463
# 2        Married-AF-spouse   <=50K     13
# 3        Married-AF-spouse    >50K     10
# 4       Married-civ-spouse   <=50K   8280
# 5       Married-civ-spouse    >50K   6690
# 6    Married-spouse-absent   <=50K    384
# 7    Married-spouse-absent    >50K     34
# 8            Never-married   <=50K  10176
# 9            Never-married    >50K    491
# 10               Separated   <=50K    959
# 11               Separated    >50K     66
# 12                 Widowed   <=50K    908
# 13                 Widowed    >50K     85

# %%
df3 = df.groupby("marital-status")["income"].value_counts().reset_index()

# %%
df3.groupby("marital-status").agg({"count" : "sum"}).reset_index()
# Out:
#            marital-status  count
# 0                Divorced   4441
# 1       Married-AF-spouse     23
# 2      Married-civ-spouse  14970
# 3   Married-spouse-absent    418
# 4           Never-married  10667
# 5               Separated   1025
# 6                 Widowed    993

# %%
df4 = df3.groupby("marital-status").agg({"count" : "sum"}).reset_index()

mar_inc_df = df3.merge(df4, on="marital-status",how="left")
mar_inc_df = mar_inc_df.rename(columns={"count_x" : "mar_inc_count", "count_y" : "mar_total_count"})

# %%
mar_inc_df
# Out:
#             marital-status  income  mar_inc_count  mar_total_count
# 0                 Divorced   <=50K           3978             4441
# 1                 Divorced    >50K            463             4441
# 2        Married-AF-spouse   <=50K             13               23
# 3        Married-AF-spouse    >50K             10               23
# 4       Married-civ-spouse   <=50K           8280            14970
# 5       Married-civ-spouse    >50K           6690            14970
# 6    Married-spouse-absent   <=50K            384              418
# 7    Married-spouse-absent    >50K             34              418
# 8            Never-married   <=50K          10176            10667
# 9            Never-married    >50K            491            10667
# 10               Separated   <=50K            959             1025
# 11               Separated    >50K             66             1025
# 12                 Widowed   <=50K            908              993
# ...

# %%
mar_inc_df["percent"] = round((mar_inc_df["mar_inc_count"]/mar_inc_df["mar_total_count"])*100,2)

# %%
mar_inc_df
# Out:
#             marital-status  income  mar_inc_count  mar_total_count  percent
# 0                 Divorced   <=50K           3978             4441    89.57
# 1                 Divorced    >50K            463             4441    10.43
# 2        Married-AF-spouse   <=50K             13               23    56.52
# 3        Married-AF-spouse    >50K             10               23    43.48
# 4       Married-civ-spouse   <=50K           8280            14970    55.31
# 5       Married-civ-spouse    >50K           6690            14970    44.69
# 6    Married-spouse-absent   <=50K            384              418    91.87
# 7    Married-spouse-absent    >50K             34              418     8.13
# 8            Never-married   <=50K          10176            10667    95.40
# 9            Never-married    >50K            491            10667     4.60
# 10               Separated   <=50K            959             1025    93.56
# ...

# %%
plt.figure(figsize=(10,6))
plt.suptitle("Bivariate Analysis between marital-status and income", fontsize = 20, fontweight = "bold", alpha = 0.8, y=1.)

sns.barplot(mar_inc_df, x = "percent", y = "marital-status", hue="income", palette="Set2")
plt.tight_layout()

# %%
# Observation : Married indiviual with civilian spouse or armed forces spouse has higher chances of making over 50k

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
# Bivariate analysis between occupation and income
df5 = df.groupby("occupation")["income"].value_counts().reset_index()
df6 = df5.groupby("occupation")["count"].sum().reset_index()

# Normalise or merge
df5 = df5.merge(df6, on="occupation", how="left")

# Rename columns
df5 = df5.rename(columns={"count_x" : "occ_inc_count", "count_y" : "occ_total_count"})

# Percent column
df5["percent"] = round((df5["occ_inc_count"]/df5["occ_total_count"])*100, 2)

occ_inc_df = df5

# %%
df5.head()
# Out:
#       occupation  income  occ_inc_count  occ_total_count  percent
# 0              ?   <=50K           1652             1843    89.64
# 1              ?    >50K            191             1843    10.36
# 2   Adm-clerical   <=50K           3261             3768    86.54
# 3   Adm-clerical    >50K            507             3768    13.46
# 4   Armed-Forces   <=50K              8                9    88.89

# %%
plt.figure(figsize=(10,5))
plt.suptitle("Bivariate analysis between occupation and income in percentage", fontsize = 20, fontweight = "bold", alpha = 0.8, y = 1.)
sns.barplot(occ_inc_df, x = "percent", y = "occupation", hue="income", palette="Set2")
plt.tight_layout()

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# # race vs income

# %%
# Bivariate analysis between race and income
df5 = df.groupby("race")["income"].value_counts().reset_index()
df6 = df5.groupby("race")["count"].sum().reset_index()

# Normalise or merge
df5 = df5.merge(df6, on="race", how="left")

# Rename columns
df5 = df5.rename(columns={"count_x" : "rac_inc_count", "count_y" : "rac_total_count"})

# Percent column
df5["percent"] = round((df5["rac_inc_count"]/df5["rac_total_count"])*100, 2)

rac_inc_df = df5

# %%
plt.figure(figsize=(10,5))
plt.suptitle("Bivariate analysis between race and income in percentage", fontsize = 20, fontweight = "bold", alpha = 0.8, y = 1.)
sns.barplot(rac_inc_df, x = "percent", y = "race", hue="income", palette="Set2")
plt.tight_layout()

# %% [markdown]
# # sex vs income

# %%
# Bivariate analysis between race and income
df5 = df.groupby("sex")["income"].value_counts().reset_index()
df6 = df5.groupby("sex")["count"].sum().reset_index()

# Normalise or merge
df5 = df5.merge(df6, on="sex", how="left")

# Rename columns
df5 = df5.rename(columns={"count_x" : "sex_inc_count", "count_y" : "sex_total_count"})

# Percent column
df5["percent"] = round((df5["sex_inc_count"]/df5["sex_total_count"])*100, 2)

sex_inc_df = df5

# %%
sex_inc_df
# Out:
#        sex  income  sex_inc_count  sex_total_count  percent
# 0   Female   <=50K           9583            10762    89.04
# 1   Female    >50K           1179            10762    10.96
# 2     Male   <=50K          15115            21775    69.41
# 3     Male    >50K           6660            21775    30.59

# %%
# plot
plt.figure(figsize=(10,5))
plt.suptitle("Bivariate analysis between sex and income in percentage", fontsize = 20, fontweight = "bold", alpha = 0.8, y = 1.)
sns.barplot(sex_inc_df, x = "percent", y = "sex", hue="income", palette="Set2")
plt.tight_layout()

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# # native-country vs income

# %%
# Bivariate analysis between native-country and income
df5 = df.groupby("native-country")["income"].value_counts().reset_index()
df6 = df5.groupby("native-country")["count"].sum().reset_index()

# Normalise or merge
df5 = df5.merge(df6, on="native-country", how="left")

# Rename columns
df5 = df5.rename(columns={"count_x" : "con_inc_count", "count_y" : "con_total_count"})

# Percent column
df5["percent"] = round((df5["con_inc_count"]/df5["con_total_count"])*100, 2)

con_inc_df = df5

# %%
con_inc_df
# Out:
#     native-country  income  con_inc_count  con_total_count  percent
# 0                ?   <=50K            436              582    74.91
# 1                ?    >50K            146              582    25.09
# 2         Cambodia   <=50K             12               19    63.16
# 3         Cambodia    >50K              7               19    36.84
# 4           Canada   <=50K             82              121    67.77
# ..             ...     ...            ...              ...      ...
# 77   United-States    >50K           7169            29153    24.59
# 78         Vietnam   <=50K             62               67    92.54
# 79         Vietnam    >50K              5               67     7.46
# 80      Yugoslavia   <=50K             10               16    62.50
# 81      Yugoslavia    >50K              6               16    37.50
#
# [82 rows x 5 columns]

# %%
# plot
plt.figure(figsize=(10,10))
plt.suptitle("Bivariate analysis between native-country and income in percentage", fontsize = 20, fontweight = "bold", alpha = 0.8, y = 1.)
sns.barplot(con_inc_df, x = "percent", y = "native-country", hue="income", palette="Set2")
plt.tight_layout()

# %% [markdown]
# # Data Cleaning

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
# We know that workclass, occupation and native-country has unknown or incorrect category "?"

# Replace "?" with most frequent category

# %%
import statistics as stat

stat.mode(df["workclass"])
# Out:
# ' Private'

# %%
df_copy = df

# %%
df_copy.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df_copy["workclass"] = df_copy["workclass"].str.replace(" ?", stat.mode(df_copy["workclass"]))
df_copy["occupation"] = df_copy["occupation"].str.replace(" ?", stat.mode(df_copy["occupation"]))
df_copy["native-country"] = df_copy["native-country"].str.replace(" ?", stat.mode(df_copy["native-country"]))

# %%
df_copy["workclass"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
df_copy["occupation"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df_copy["native-country"].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df[df["workclass"] == " ?"]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df["workclass"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
df_copy.to_csv("./data/adult_train.csv")

# %%
# Test data

# %%
import os
pd.read_csv(os.path.join("data","adulttest.data"))
# Out:
#                                                                                                                                                      |1x3 Cross validator
# 25  Private      226802  11th         7   Never-married       Machine-op-inspct  Own-child       Black               Male   0    0 40  United-States               <=50K.
# 38  Private      89814   HS-grad      9   Married-civ-spouse  Farming-fishing    Husband         White               Male   0    0 50  United-States               <=50K.
# 28  Local-gov    336951  Assoc-acdm   12  Married-civ-spouse  Protective-serv    Husband         White               Male   0    0 40  United-States                >50K.
# 44  Private      160323  Some-college 10  Married-civ-spouse  Machine-op-inspct  Husband         Black               Male   7688 0 40  United-States                >50K.
# ...

# %%
pd.read_csv(os.path.join("data","adulttest.data"), skiprows=1, header=None,
            names= ["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race",
                                          "sex", "capital-gain", "capital-loss","hours-per-week","native-country","income"])
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 4       18              ?  103497   Some-college             10
# ...    ...            ...     ...            ...            ...
# 16276   39        Private  215419      Bachelors             13
# 16277   64              ?  321403        HS-grad              9
# 16278   38        Private  374983      Bachelors             13
# 16279   44        Private   83891      Bachelors             13
# 16280   35   Self-emp-inc  182148      Bachelors             13
#
#             marital-status          occupation     relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# 1       Married-civ-spouse     Farming-fishing          Husband
# ...

# %%
df = pd.read_csv(os.path.join("data","adulttest.data"), skiprows=1, header=None,
            names= ["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race",
                                          "sex", "capital-gain", "capital-loss","hours-per-week","native-country","income"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             16281 non-null  int64
#  1   workclass       16281 non-null  object
#  2   fnlwgt          16281 non-null  int64
#  3   education       16281 non-null  object
#  4   education-num   16281 non-null  int64
#  5   marital-status  16281 non-null  object
#  6   occupation      16281 non-null  object
#  7   relationship    16281 non-null  object
#  8   race            16281 non-null  object
#  9   sex             16281 non-null  object
#  10  capital-gain    16281 non-null  int64
#  11  capital-loss    16281 non-null  int64
#  12  hours-per-week  16281 non-null  int64
#  13  native-country  16281 non-null  object
#  14  income          16281 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.9+ MB

# %%
# Check for duplicates
df[df.duplicated()]
# Out:
#        age      workclass  fnlwgt   education  education-num  \
# 864     24        Private  194630   Bachelors             13
# 11189   37        Private   52870   Bachelors             13
# 11212   29        Private   36440   Bachelors             13
# 13848   30        Private  180317   Assoc-voc             11
# 15960   18   Self-emp-inc  378036        12th              8
#
#             marital-status          occupation    relationship    race  \
# 864          Never-married      Prof-specialty   Not-in-family   White
# 11189   Married-civ-spouse     Exec-managerial         Husband   White
# 11212        Never-married        Adm-clerical   Not-in-family   White
# 13848             Divorced   Machine-op-inspct   Not-in-family   White
# 15960        Never-married     Farming-fishing       Own-child   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 864       Male             0             0              35   United-States
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (16276, 15)

# %%
## Numerical and categorical columns

numerical_columns = df.columns[df.dtypes != "object"]
categorical_columns = df.columns[df.dtypes == "object"]

# %%
for cat in categorical_columns:
    print(cat)
    print(df[cat].unique())
    print("="*35)
    print("\n")
# Out:
# workclass
# [' Private' ' Local-gov' ' ?' ' Self-emp-not-inc' ' Federal-gov'
#  ' State-gov' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# ...
#
#
# education
# [' 11th' ' HS-grad' ' Assoc-acdm' ' Some-college' ' 10th' ' Prof-school'
#  ' 7th-8th' ' Bachelors' ' Masters' ' Doctorate' ' 5th-6th' ' Assoc-voc'
#  ' 9th' ' 12th' ' 1st-4th' ' Preschool']
# ...
#
#
# marital-status
# [' Never-married' ' Married-civ-spouse' ' Widowed' ' Divorced'
#  ' Separated' ' Married-spouse-absent' ' Married-AF-spouse']
# ...
#
#
# occupation
# [' Machine-op-inspct' ' Farming-fishing' ' Protective-serv' ' ?'
#  ' Other-service' ' Prof-specialty' ' Craft-repair' ' Adm-clerical'
#  ' Exec-managerial' ' Tech-support' ' Sales' ' Priv-house-serv'
#  ' Transport-moving' ' Handlers-cleaners' ' Armed-Forces']
# ...
#
#
# relationship
# [' Own-child' ' Husband' ' Not-in-family' ' Unmarried' ' Wife'
#  ' Other-relative']
# ...
#
#
# race
# [' Black' ' White' ' Asian-Pac-Islander' ' Other' ' Amer-Indian-Eskimo']
# ...
#
#
# sex
# ...

# %%
import copy
df_copy = copy.deepcopy(df)

df_copy["workclass"] = df_copy["workclass"].str.replace(" ?", stat.mode(df_copy["workclass"]))
df_copy["occupation"] = df_copy["occupation"].str.replace(" ?", stat.mode(df_copy["occupation"]))
df_copy["native-country"] = df_copy["native-country"].str.replace(" ?", stat.mode(df_copy["native-country"]))

# %%
df["workclass"].unique()
# Out:
# array([' Private', ' Local-gov', ' ?', ' Self-emp-not-inc',
#        ' Federal-gov', ' State-gov', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df_copy["workclass"].unique()
# Out:
# array([' Private', ' Local-gov', ' Self-emp-not-inc', ' Federal-gov',
#        ' State-gov', ' Self-emp-inc', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
df_copy.to_csv(os.path.join("data","adult_test.csv"))
